# %%
import ensembl_rest
import numpy as np
import pandas as pd

# %%
ensembl_annotation = pd.read_csv('../data/custom/ensembl_annotation_trs_uniprot_20220429.csv', low_memory=False)

# %%
with open('../data/raw/nextprot_050222_missing_pe2_20220409.txt') as f:
    missing_ac_list = f.read().splitlines()

# %%
len(missing_ac_list)
# Out:
# 1135

# %%
missing_df = pd.concat([ensembl_annotation[ensembl_annotation['uniprot_base']==ac] for ac in missing_ac_list])

unmapped = list(set(missing_ac_list).difference(missing_df['uniprot_base'].to_list()))
unmapped.sort()

with open('../reports/mapping/missing_ensembl_unmapped_20220411.txt', 'w') as f:
    for i in unmapped:
        f.write(f'{i}\n')

# %%
len(unmapped)
# Out:
# 237

# %%
def get_length_aa(enst_list: list):
    length_aa = []
    enst_info = {}
    
    chunk_size = 100
    enst_chunks = (enst_list[pos:pos + chunk_size] for pos in range(0, len(enst_list), chunk_size))
    
    for i in enst_chunks:
        enst_info.update(ensembl_rest.lookup_post(species='human', params={'expand': True, 'ids': i}))
    
    for e in enst_list:
        try:
            length_aa.append(enst_info[e]['Translation']['length'])
        except TypeError:
            length_aa.append(np.nan)
        
    return length_aa

missing_df['protein_length_aa'] = get_length_aa(missing_df['ensembl_trs_id'].to_list())

# %%
missing_df = missing_df[['ensembl_gene_name', 'uniprot_isoform', 'protein_length_aa', 
                         'ensembl_trs_id', 'ensembl_is_canonical', 'trs_length_bp']]

missing_df.to_csv('../data/processed/missing_ensembl_mapping_all_20220411.csv', index=False)

# %%
missing_df
# Out:
#        ensembl_gene_name uniprot_isoform  protein_length_aa   ensembl_trs_id  \
# 214034          TRBV24-1    A0A075B6N3-1                115  ENST00000390397
# 214037          TRBV25-1    A0A075B6N4-1                114  ENST00000390398
# 213937             TRAV6    A0A075B6T7-1                132  ENST00000390428
# 213938             TRAV7    A0A075B6U4-1                112  ENST00000390429
# 213928         TRAV36DV7    A0A075B6V5-1                113  ENST00000390463
# ...                  ...             ...                ...              ...
# 144711            OR51B4        Q9Y5P0-1                310  ENST00000380224
# 173939            RNF215        Q9Y6U7-1                377  ENST00000382363
# 129869         MTRNR2L13        S4R3P1-1                 24  ENST00000604093
# 129867         MTRNR2L11        S4R3Y5-1                 24  ENST00000604646
# 101              A3GALT2        U3KPV4-1                340  ENST00000442999
#
#         ensembl_is_canonical  trs_length_bp
# 214034                  True            381
# 214037                  True            381
# 213937                  True            404
# 213938                  True            337
# 213928                  True            356
# ...                      ...            ...
# 144711                  True            933
# 173939                  True           2011
# 129869                  True           1445
# 129867                  True           1552
# 101                     True           1023
#
# [1513 rows x 6 columns]

# %%
line_names = ['A549', 'Caco2', 'HaCaT', 'Hek293T', 'HeLa', 'HepG2', 'Huh7', 'MCF7', 'Saos2', 'SKBR3', 'U2OS']

# %%
line_files = [pd.read_excel(f'../data/custom/va_lines/{i}.xlsx')
              .set_index('transcript_id', drop=True).iloc[:, [-1]] 
              for i in line_names]

# %%
lines_df = line_files[0].join(line_files[1:], how='outer')

# %%
lines_df.index.name= 'ensembl_trs_id'

# %%
lines_df = lines_df.fillna(0)

# %%
lines_df.to_csv('../data/processed/va_lines_expression_proteincoding_trs.csv')

# %%
lines_df = pd.read_csv('../data/processed/va_lines_expression_proteincoding_trs.csv', index_col=0)

# %%
lines_df
# Out:
#                      A549     Caco2     HaCaT   HEK293T       HeLa     HepG2  \
# ensembl_trs_id
# ENST00000440075  0.256721  9.788971  0.407386  0.000000   0.000000  0.159880
# ENST00000398101  0.433563  0.367757  0.000000  0.058994   0.021996  0.000000
# ENST00000261219  0.175636  0.417713  0.674782  0.068071   0.000000  0.154386
# ENST00000537360  0.548286  0.265523  0.044893  0.038378   0.054987  0.070682
# ENST00000367067  1.626066  1.568156  0.634107  0.000000  27.164890  0.620189
# ...                   ...       ...       ...       ...        ...       ...
# ENST00000674031  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# ENST00000674194  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# ENST00000675459  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# ENST00000675842  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# ENST00000678254  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
#
#                      Huh7      MCF7     SAOS2     SKBR3      U2OS
# ensembl_trs_id
# ENST00000440075  0.065040  0.000000  0.000000  0.184198  0.000000
# ENST00000398101  0.222245  0.066869  1.224826  1.930838  3.093246
# ENST00000261219  0.116461  0.293679  0.791766  1.853371  0.643787
# ENST00000537360  0.033041  0.000000  0.108896  0.211980  0.049342
# ENST00000367067  0.172326  0.980916  2.233141  1.346990  1.843781
# ...                   ...       ...       ...       ...       ...
# ENST00000674031  0.000000  0.000000  0.000000  0.000000  0.531759
# ENST00000674194  0.000000  0.000000  0.000000  0.000000  0.039345
# ENST00000675459  0.000000  0.000000  0.000000  0.000000  0.021859
# ENST00000675842  0.000000  0.000000  0.000000  0.000000  0.007865
# ENST00000678254  0.000000  0.000000  0.000000  0.000000  0.040456
#
# [57162 rows x 11 columns]

# %%
lines_df.columns = [f'{i.lower()}_tpm' for i in lines_df.columns]

# %%
lines_df
# Out:
#                  a549_tpm  caco2_tpm  hacat_tpm  hek293t_tpm   hela_tpm  \
# ensembl_trs_id
# ENST00000440075  0.256721   9.788971   0.407386     0.000000   0.000000
# ENST00000398101  0.433563   0.367757   0.000000     0.058994   0.021996
# ENST00000261219  0.175636   0.417713   0.674782     0.068071   0.000000
# ENST00000537360  0.548286   0.265523   0.044893     0.038378   0.054987
# ENST00000367067  1.626066   1.568156   0.634107     0.000000  27.164890
# ...                   ...        ...        ...          ...        ...
# ENST00000674031  0.000000   0.000000   0.000000     0.000000   0.000000
# ENST00000674194  0.000000   0.000000   0.000000     0.000000   0.000000
# ENST00000675459  0.000000   0.000000   0.000000     0.000000   0.000000
# ENST00000675842  0.000000   0.000000   0.000000     0.000000   0.000000
# ENST00000678254  0.000000   0.000000   0.000000     0.000000   0.000000
#
#                  hepg2_tpm  huh7_tpm  mcf7_tpm  saos2_tpm  skbr3_tpm  u2os_tpm
# ensembl_trs_id
# ENST00000440075   0.159880  0.065040  0.000000   0.000000   0.184198  0.000000
# ENST00000398101   0.000000  0.222245  0.066869   1.224826   1.930838  3.093246
# ENST00000261219   0.154386  0.116461  0.293679   0.791766   1.853371  0.643787
# ENST00000537360   0.070682  0.033041  0.000000   0.108896   0.211980  0.049342
# ENST00000367067   0.620189  0.172326  0.980916   2.233141   1.346990  1.843781
# ...                    ...       ...       ...        ...        ...       ...
# ENST00000674031   0.000000  0.000000  0.000000   0.000000   0.000000  0.531759
# ENST00000674194   0.000000  0.000000  0.000000   0.000000   0.000000  0.039345
# ENST00000675459   0.000000  0.000000  0.000000   0.000000   0.000000  0.021859
# ENST00000675842   0.000000  0.000000  0.000000   0.000000   0.000000  0.007865
# ENST00000678254   0.000000  0.000000  0.000000   0.000000   0.000000  0.040456
#
# [57162 rows x 11 columns]

# %%
missing_df = pd.read_csv('../data/processed/missing_ensembl_mapping_all_20220411.csv')

# %%
missing_df = missing_df.join(lines_df, on='ensembl_trs_id', how='left').fillna(0)

# %%
missing_df.to_excel('../reports/mapping/missing_ensembl_expression_all_lines_20220607.xlsx', index=False)

# %%
hek293t_repl = [pd.read_csv(f'../data/custom/va_hek293t/HEK293T_{i}.sf', sep='\t')
                .set_index('Name', drop=True)
                .loc[:, ['TPM']]
                .rename({'TPM':f'HEK293T-{i}'}, axis=1) 
                for i in range(1,4)]

# %%
for i in hek293t_repl:
    i.index = i.index.map(lambda x: x[:x.index('.')])

# %%
hek293t_df = hek293t_repl[0].join(hek293t_repl[1:])

# %%
hek293t_df['TPM'] = hek293t_df.mean(axis=1)

# %%
hek293t_df.index.name = 'ensembl_trs_id'

# %%
hek293t_df.to_csv('../data/processed/va_hek293t_expression_all_trs.csv')

# %%
hek293t_df = pd.read_csv('../data/processed/va_hek293t_expression_all_trs.csv', index_col=0)

# %%
hek293t_repl[0].shape
# Out:
# (196722, 1)

# %%
hek293t_repl[1].shape
# Out:
# (196722, 1)

# %%
hek293t_repl[2].shape
# Out:
# (196722, 1)

# %%
missing_expression_good_sum = missing_df.groupby('uniprot_isoform')['hek293t_tpm'].sum() > 4
missing_expression_good_sum = missing_expression_good_sum[missing_expression_good_sum == True].index

missing_select_df = missing_df[(missing_df['protein_length_aa'] > 80) & (missing_df['uniprot_isoform'].isin(missing_expression_good_sum))]

missing_select_df = missing_select_df.sort_values(['ensembl_gene_name', 'uniprot_isoform'])

missing_select_df = missing_select_df.set_index(['ensembl_gene_name', 'uniprot_isoform', 'protein_length_aa', 'ensembl_trs_id'], drop=True)

missing_select_df = missing_select_df.loc[:, ['ensembl_is_canonical', 'trs_length_bp', 'hek293t_tpm']]

missing_select_df.to_excel('../reports/selection/missing_select_hek_20220607.xlsx')

# %%
missing_select_df
# Out:
#                                                                      ensembl_is_canonical  \
# ensembl_gene_name uniprot_isoform protein_length_aa ensembl_trs_id
# AGAP9             Q5VTM2-2        658               ENST00000452145                  True
# ASAH2B            P0C7U1-1        165               ENST00000643851                 False
#                                                     ENST00000374006                 False
#                   P0C7U1-2        160               ENST00000374007                 False
#                                                     ENST00000647317                  True
# C1orf54           Q8WWF1-1        131               ENST00000369102                 False
#                                                     ENST00000369099                  True
# CNPY1             Q3B7I2-1        92                ENST00000406197                 False
#                                                     ENST00000321736                 False
# CTXN1             P60606-1        82                ENST00000318978                  True
# CYB5RL            Q6IPT4-4        247               ENST00000287899                 False
# EOLA2             Q96DE9-1        158               ENST00000370406                  True
#                                                     ENST00000355203                 False
#                                                     ENST00000370404                 False
# FAM72C            H0Y354-1        149               ENST00000584486                  True
# GAGE13            Q4V321-1        117               ENST00000612958                  True
# GOLGA8A           A7E2F4-1        631               ENST00000432566                 False
#                   A7E2F4-3        603               ENST00000359187                  True
# LRRC75B           Q2VPJ9-1        315               ENST00000318753                  True
# MOSMO             Q8NHV5-1        167               ENST00000542527                  True
# NBPF11            Q86T75-1        865               ENST00000614015                 False
#                                                     ENST00000615281                 False
# NBPF12            Q5TAG4-1        1457              ENST00000617931                  True
#                                                     ENST00000617844                 False
# NBPF15            Q8N660-1        670               ENST00000488031                 False
#                                                     ENST00000581897                  True
#                                                     ENST00000577412                 False
# NPIPA1            Q9UND3-1        350               ENST00000328085                  True
# PPM1N             Q8N819-3        112               ENST00000401705                 False
#                                                     ENST00000396737                 False
#                                                     ENST00000396735                 False
# RNF215            Q9Y6U7-1        377               ENST00000382363                  True
# TLCD5             Q6ZRR5-1        245               ENST00000375095                  True
# TMEM81            Q6P7N7-1        255               ENST00000367167                  True
# TSPAN17           Q96FV3-2        188               ENST00000298564                 False
#                   Q96FV3-3        263               ENST00000515708                 False
#                   Q96FV3-4        329               ENST00000508164                  True
#
#                                                                      trs_length_bp  \
# ensembl_gene_name uniprot_isoform protein_length_aa ensembl_trs_id
# AGAP9             Q5VTM2-2        658               ENST00000452145           2387
# ASAH2B            P0C7U1-1        165               ENST00000643851           5005
#                                                     ENST00000374006            632
#                   P0C7U1-2        160               ENST00000374007           3715
#                                                     ENST00000647317           5145
# C1orf54           Q8WWF1-1        131               ENST00000369102           1251
#                                                     ENST00000369099            509
# CNPY1             Q3B7I2-1        92                ENST00000406197            560
#                                                     ENST00000321736           2378
# CTXN1             P60606-1        82                ENST00000318978           1237
# CYB5RL            Q6IPT4-4        247               ENST00000287899           5777
# EOLA2             Q96DE9-1        158               ENST00000370406           1333
#                                                     ENST00000355203           1067
#                                                     ENST00000370404           1316
# FAM72C            H0Y354-1        149               ENST00000584486           2395
# GAGE13            Q4V321-1        117               ENST00000612958            561
# GOLGA8A           A7E2F4-1        631               ENST00000432566           4577
#                   A7E2F4-3        603               ENST00000359187           5777
# LRRC75B           Q2VPJ9-1        315               ENST00000318753           1233
# MOSMO             Q8NHV5-1        167               ENST00000542527           4469
# NBPF11            Q86T75-1        865               ENST00000614015           4630
#                                                     ENST00000615281           5494
# NBPF12            Q5TAG4-1        1457              ENST00000617931           7061
#                                                     ENST00000617844           6326
# NBPF15            Q8N660-1        670               ENST00000488031           4535
#                                                     ENST00000581897           4862
#                                                     ENST00000577412           4649
# NPIPA1            Q9UND3-1        350               ENST00000328085           1084
# PPM1N             Q8N819-3        112               ENST00000401705            771
#                                                     ENST00000396737            872
#                                                     ENST00000396735            895
# RNF215            Q9Y6U7-1        377               ENST00000382363           2011
# TLCD5             Q6ZRR5-1        245               ENST00000375095           3980
# TMEM81            Q6P7N7-1        255               ENST00000367167           1332
# TSPAN17           Q96FV3-2        188               ENST00000298564           2810
#                   Q96FV3-3        263               ENST00000515708           2361
#                   Q96FV3-4        329               ENST00000508164           2475
#
#                                                                      hek293t_tpm
# ensembl_gene_name uniprot_isoform protein_length_aa ensembl_trs_id
# AGAP9             Q5VTM2-2        658               ENST00000452145    17.906937
# ASAH2B            P0C7U1-1        165               ENST00000643851     1.375991
#                                                     ENST00000374006     3.907073
#                   P0C7U1-2        160               ENST00000374007     3.989175
#                                                     ENST00000647317     2.919516
# C1orf54           Q8WWF1-1        131               ENST00000369102     0.369875
#                                                     ENST00000369099     9.431817
# CNPY1             Q3B7I2-1        92                ENST00000406197    19.871630
#                                                     ENST00000321736     8.023424
# CTXN1             P60606-1        82                ENST00000318978     9.340649
# CYB5RL            Q6IPT4-4        247               ENST00000287899     5.427784
# EOLA2             Q96DE9-1        158               ENST00000370406    60.381194
#                                                     ENST00000355203    31.511149
#                                                     ENST00000370404    21.220853
# FAM72C            H0Y354-1        149               ENST00000584486    10.061995
# GAGE13            Q4V321-1        117               ENST00000612958     5.474270
# GOLGA8A           A7E2F4-1        631               ENST00000432566     5.411162
#                   A7E2F4-3        603               ENST00000359187     5.787899
# LRRC75B           Q2VPJ9-1        315               ENST00000318753     4.676983
# MOSMO             Q8NHV5-1        167               ENST00000542527     4.896428
# NBPF11            Q86T75-1        865               ENST00000614015     3.659240
#                                                     ENST00000615281     7.718868
# NBPF12            Q5TAG4-1        1457              ENST00000617931     4.277930
#                                                     ENST00000617844     4.993200
# NBPF15            Q8N660-1        670               ENST00000488031    11.751500
#                                                     ENST00000581897    12.067663
#                                                     ENST00000577412     7.391319
# NPIPA1            Q9UND3-1        350               ENST00000328085     6.668239
# PPM1N             Q8N819-3        112               ENST00000401705     1.719413
#                                                     ENST00000396737     8.652978
#                                                     ENST00000396735     0.359642
# RNF215            Q9Y6U7-1        377               ENST00000382363     5.529197
# TLCD5             Q6ZRR5-1        245               ENST00000375095     6.747156
# TMEM81            Q6P7N7-1        255               ENST00000367167     7.748528
# TSPAN17           Q96FV3-2        188               ENST00000298564    11.217715
#                   Q96FV3-3        263               ENST00000515708    10.122305
#                   Q96FV3-4        329               ENST00000508164    18.437209

# %%
missing_df[(missing_df['protein_length_aa'] > 80) & (missing_df['hek293t_tpm'] > 4)]
# Out:
#      ensembl_gene_name uniprot_isoform  protein_length_aa   ensembl_trs_id  \
# 278            GOLGA8A        A7E2F4-1                631  ENST00000432566
# 279            GOLGA8A        A7E2F4-3                603  ENST00000359187
# 337             FAM72C        H0Y354-1                149  ENST00000584486
# 578              CTXN1        P60606-1                 82  ENST00000318978
# 626            LRRC75B        Q2VPJ9-1                315  ENST00000318753
# 635              CNPY1        Q3B7I2-1                 92  ENST00000406197
# 636              CNPY1        Q3B7I2-1                 92  ENST00000321736
# 666             GAGE13        Q4V321-1                117  ENST00000612958
# 704             NBPF12        Q5TAG4-1               1457  ENST00000617931
# 705             NBPF12        Q5TAG4-1               1457  ENST00000617844
# 716              AGAP9        Q5VTM2-2                658  ENST00000452145
# 791             CYB5RL        Q6IPT4-4                247  ENST00000287899
# 800             TMEM81        Q6P7N7-1                255  ENST00000367167
# 831              TLCD5        Q6ZRR5-1                245  ENST00000375095
# 875             NBPF11        Q86T75-1                865  ENST00000615281
# 945             NBPF15        Q8N660-1                670  ENST00000488031
# 946             NBPF15        Q8N660-1                670  ENST00000581897
# 947             NBPF15        Q8N660-1                670  ENST00000577412
# 961              PPM1N        Q8N819-3                112  ENST00000396737
# 1177             MOSMO        Q8NHV5-1                167  ENST00000542527
# 1189           C1orf54        Q8WWF1-1                131  ENST00000369099
# 1217             EOLA2        Q96DE9-1                158  ENST00000370406
# 1218             EOLA2        Q96DE9-1                158  ENST00000355203
# 1219             EOLA2        Q96DE9-1                158  ENST00000370404
# 1220           TSPAN17        Q96FV3-2                188  ENST00000298564
# 1221           TSPAN17        Q96FV3-3                263  ENST00000515708
# 1222           TSPAN17        Q96FV3-4                329  ENST00000508164
# 1485            NPIPA1        Q9UND3-1                350  ENST00000328085
# 1509            RNF215        Q9Y6U7-1                377  ENST00000382363
#
#       ensembl_is_canonical  trs_length_bp   a549_tpm  caco2_tpm  hacat_tpm  \
# 278                  False           4577   0.057092   1.461287   1.214195
# 279                   True           5777   0.000000   1.638568   3.221302
# 337                   True           2395   6.043067   0.661529   5.208124
# 578                   True           1237  20.658080   2.203673   6.683739
# 626                   True           1233   3.238652   0.000000   0.659198
# 635                  False            560   0.101300   0.000000   0.000000
# 636                  False           2378   0.006150   0.067968   0.000000
# 666                   True            561   0.000000   0.020393   0.000000
# 704                   True           7061   0.718152   0.752975   0.409628
# 705                  False           6326   0.994998   0.736180   0.774347
# 716                   True           2387   1.384196   2.817019   4.574160
# 791                  False           5777   1.007788   1.179410   2.101853
# 800                   True           1332   1.941012   2.018261   0.360647
# 831                   True           3980   0.194432   0.244634   0.000000
# 875                  False           5494   0.831373   1.348609   0.416409
# 945                  False           4535   2.351269   1.528499   1.551265
# 946                   True           4862   1.480652   0.922126   1.576239
# 947                  False           4649   0.717775   0.434955   1.031390
# 961                  False            872   5.322741   1.453533   3.565501
# 1177                  True           4469   2.830591   1.917031   1.559788
# 1189                  True            509   0.000000   0.000000   0.091938
# 1217                  True           1333  15.201429   4.377966  10.594487
# 1218                 False           1067   1.467361   2.448588   3.695295
# 1219                 False           1316   3.922795   1.655072   4.421778
# 1220                 False           2810  10.549125   2.840110   3.833987
# 1221                 False           2361   6.044170   0.993044   4.055006
# 1222                  True           2475  16.908851   2.439428   9.024438
# 1485                  True           1084   2.092525   1.125259   4.881547
# 1509                  True           2011   5.285270   1.647353   0.719113
#
#       hek293t_tpm   hela_tpm  hepg2_tpm  huh7_tpm  mcf7_tpm  saos2_tpm  \
# 278      5.411162  19.582925   1.519552  4.410374  0.944994  14.366107
# 279      5.787899  10.371453   2.729271  4.621757  0.244215   3.641828
# 337     10.061995   7.204449   4.056322  0.540621  1.101150  28.592691
# 578      9.340649  19.286514   1.021377  5.117358  1.525792   9.222452
# 626      4.676983   0.520652   2.624748  1.296385  0.069811   0.235021
# 635     19.871630   0.000000   0.000000  0.000000  0.000000   0.000000
# 636      8.023424   0.000000   0.000000  0.000000  0.012038   0.011481
# 666      5.474270   0.000000   0.000000  0.000000  0.000000   0.558240
# 704      4.277930   0.912415   1.059471  1.113211  2.444306   5.744109
# 705      4.993200   0.807365   1.123835  1.519643  3.311536   8.377505
# 716     17.906937   1.187622   3.108175  1.215079  1.036301   4.279543
# 791      5.427784   4.649491   1.230707  1.223768  0.815421   4.076181
# 800      7.748528   3.576580   0.743969  1.713194  1.702714   1.633669
# 831      6.747156   1.805423   1.284517  0.061625  0.801986   2.154301
# 875      7.718868   1.561547   1.479326  0.977333  1.710221  10.322086
# 945     11.751500   3.611456   2.143092  1.141428  4.113598  12.317587
# 946     12.067663   2.905910   1.960829  1.532459  4.747820  11.950116
# 947      7.391319   2.147097   1.424502  0.550721  3.763192   6.968021
# 961      8.652978   0.562149   0.570702  0.292686  0.362830   0.168161
# 1177     4.896428   4.601605   5.340701  1.447509  2.115228   5.336305
# 1189     9.431817   0.000000   0.000000  0.000000  0.090348   0.000000
# 1217    60.381194  13.047703   7.832021  4.662670  4.227102  27.667388
# 1218    31.511149   7.337273   4.599463  1.986554  8.987022   5.406917
# 1219    21.220853   3.514450   2.547267  1.958752  2.625258   5.534509
# 1220    11.217715   4.267469   3.339147  2.285251  1.959467   8.765736
# 1221    10.122305   4.186802   3.566693  1.178557  4.886706   1.897223
# 1222    18.437209   8.637304   6.876869  1.649887  7.068464   8.788122
# 1485     6.668239   4.601834  11.277288  1.620894  4.243043  10.753287
# 1509     5.529197   3.667213   1.321955  0.807003  0.569393   4.409947
#
#       skbr3_tpm   u2os_tpm
# 278    0.995823   0.494476
# 279    0.000000   3.331525
# 337    4.806708   9.141472
# 578    3.956297  57.701609
# 626    0.000000   1.438137
# 635    0.000000   0.067358
# 636    0.000000   0.062071
# 666    0.000000   6.362945
# 704    3.520980   2.556022
# 705    2.686668   2.402899
# 716    7.349134   8.924208
# 791    1.751003   2.253859
# 800    2.854985   1.686181
# 831    0.000000   1.802180
# 875    3.174295   2.989711
# 945    3.325064   5.798134
# 946    3.124002   5.282339
# 947    3.205865   3.004924
# 961    1.500896   1.009812
# 1177   2.527702   3.198846
# 1189   0.182339   0.792343
# 1217   7.887798   8.232559
# 1218   3.503079   0.345526
# 1219   3.220034   3.173466
# 1220   5.702428  16.022746
# 1221   3.386905   5.186994
# 1222   7.195644  30.876791
# 1485   1.343871   1.200587
# 1509   1.348681   5.281020

# %%
missing_select_df = pd.read_excel('../reports/selection/missing_select_hek_20220607.xlsx', index_col=[0,1,2,3])

# %%
missing_select_df.index.get_level_values('ensembl_gene_name').unique()
# Out:
# Index(['AGAP9', 'ASAH2B', 'C1orf54', 'CNPY1', 'CTXN1', 'CYB5RL', 'EOLA2',
#        'FAM72C', 'GAGE13', 'GOLGA8A', 'LRRC75B', 'MOSMO', 'NBPF11', 'NBPF12',
#        'NBPF15', 'NPIPA1', 'PPM1N', 'RNF215', 'TLCD5', 'TMEM81', 'TSPAN17'],
#       dtype='object', name='ensembl_gene_name')

# %%
missing_select_df.index['ensembl_gene_name'].unique()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 missing_select_df.index['ensembl_gene_name'].unique()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\multi.py:2075, in MultiIndex.__getitem__(self, key)
#    2073 retval = []
#    2074 for lev, level_codes in zip(self.levels, self.codes):
# -> 2075     if level_codes[key] == -1:
#    2076         retval.append(np.nan)
#    2077     else:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
all_trs = ensembl_annotation[ensembl_annotation['ensembl_gene_name'].isin(missing_select_df.index.get_level_values('ensembl_gene_name').unique())]

# %%
all_trs['hek293_tpm'] = all_trs['ensembl_trs_id'].map(hek293t_df['TPM'])
# Out:
# C:\Users\Dynev\AppData\Local\Temp\ipykernel_1620\759376880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_trs['hek293_tpm'] = all_trs['ensembl_trs_id'].map(hek293t_df['TPM'])

# %%
all_trs = all_trs.drop(['ensembl_gene_id', 'trs_length_bp', 'ensembl_protein_id', 'uniprot_base'], axis=1)

# %%
all_trs
# Out:
#        ensembl_gene_name   ensembl_trs_id  ensembl_is_canonical  \
# 5288               AGAP9  ENST00000452145                  True
# 13420             ASAH2B  ENST00000643851                 False
# 13421             ASAH2B  ENST00000374006                 False
# 13422             ASAH2B  ENST00000374007                 False
# 13423             ASAH2B  ENST00000647317                  True
# ...                  ...              ...                   ...
# 216480           TSPAN17  ENST00000514705                 False
# 216481           TSPAN17  ENST00000503030                 False
# 216482           TSPAN17  ENST00000504168                 False
# 216483           TSPAN17  ENST00000503045                 False
# 216484           TSPAN17  ENST00000507471                 False
#
#                        trs_type uniprot_isoform  hek293_tpm
# 5288             protein_coding        Q5VTM2-2   17.906937
# 13420            protein_coding        P0C7U1-1    1.375991
# 13421            protein_coding        P0C7U1-1    3.907073
# 13422            protein_coding        P0C7U1-2    3.989175
# 13423            protein_coding        P0C7U1-2    2.919516
# ...                         ...             ...         ...
# 216480          retained_intron             NaN    2.486381
# 216481  nonsense_mediated_decay             NaN    0.000000
# 216482           protein_coding             NaN    0.483052
# 216483           protein_coding             NaN    1.833010
# 216484           protein_coding             NaN    6.546220
#
# [122 rows x 6 columns]

# %%
def get_enst_name(enst_list: list):
    length_aa = []
    enst_info = {}
    
    chunk_size = 100
    enst_chunks = (enst_list[pos:pos + chunk_size] for pos in range(0, len(enst_list), chunk_size))
    
    for i in enst_chunks:
        enst_info.update(ensembl_rest.lookup_post(species='human', params={'expand': True, 'ids': i}))
    
    for e in enst_list:
        try:
            length_aa.append(enst_info[e]['display_name'])
        except TypeError:
            length_aa.append(np.nan)
        
    return length_aa

# %%
all_trs['ensembl_trs_name'] = get_enst_name(all_trs['ensembl_trs_id'].to_list())

# %%
all_trs = all_trs[all_trs.columns[:2].to_list() + ['ensembl_trs_name'] + all_trs.columns[2:-1].to_list()]

# %%
all_trs = all_trs.set_index(['ensembl_gene_name', 'ensembl_trs_id'], drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 all_trs = all_trs.set_index(['ensembl_gene_name', 'ensembl_trs_id'], drop=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['ensembl_gene_name', 'ensembl_trs_id'] are in the columns"

# %%
all_trs.to_excel('../reports/selection/missing_select_hek_all_trs_20220607.xlsx')

# %%
all_trs
# Out:
#                                   ensembl_trs_name  ensembl_is_canonical  \
# ensembl_gene_name ensembl_trs_id
# AGAP9             ENST00000452145        AGAP9-201                  True
# ASAH2B            ENST00000643851       ASAH2B-205                 False
#                   ENST00000374006       ASAH2B-201                 False
#                   ENST00000374007       ASAH2B-202                 False
#                   ENST00000647317       ASAH2B-207                  True
# ...                                            ...                   ...
# TSPAN17           ENST00000514705      TSPAN17-208                 False
#                   ENST00000503030      TSPAN17-203                 False
#                   ENST00000504168      TSPAN17-205                 False
#                   ENST00000503045      TSPAN17-204                 False
#                   ENST00000507471      TSPAN17-206                 False
#
#                                                   trs_type uniprot_isoform  \
# ensembl_gene_name ensembl_trs_id
# AGAP9             ENST00000452145           protein_coding        Q5VTM2-2
# ASAH2B            ENST00000643851           protein_coding        P0C7U1-1
#                   ENST00000374006           protein_coding        P0C7U1-1
#                   ENST00000374007           protein_coding        P0C7U1-2
#                   ENST00000647317           protein_coding        P0C7U1-2
# ...                                                    ...             ...
# TSPAN17           ENST00000514705          retained_intron             NaN
#                   ENST00000503030  nonsense_mediated_decay             NaN
#                   ENST00000504168           protein_coding             NaN
#                   ENST00000503045           protein_coding             NaN
#                   ENST00000507471           protein_coding             NaN
#
#                                    hek293_tpm
# ensembl_gene_name ensembl_trs_id
# AGAP9             ENST00000452145   17.906937
# ASAH2B            ENST00000643851    1.375991
#                   ENST00000374006    3.907073
#                   ENST00000374007    3.989175
#                   ENST00000647317    2.919516
# ...                                       ...
# TSPAN17           ENST00000514705    2.486381
#                   ENST00000503030    0.000000
#                   ENST00000504168    0.483052
#                   ENST00000503045    1.833010
#                   ENST00000507471    6.546220
#
# [122 rows x 5 columns]

# %%
class GenRange:
    def __init__(self, start, stop):
        self.start = start
        self.stop = stop

# %%
class GenRangeAgg:
    def __init__(self, )
